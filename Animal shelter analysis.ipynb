# %% [markdown]
# Trying animal shelter classification

# %%
with open("iris-data.csv") as csvfile:
    iris = csv.reader(csvfile)
    for row in iris:
         print(', '.join(row))
# Out:
# , , , , , , criteria for counts, SepalLength, SepalWidth, PetalLength, PetalWidth
# , , , , , , , , , ,
# , , , , , , , , , ,
# , , , , , , , , , ,
# , , , , , , , , , ,
# , , , , , , , , , ,
# , , , , , , , , , ,
# , , , , , , , , , ,
# , , , , , , , , , ,
# SepalLength, SepalWidth, PetalLength, PetalWidth, Name, random number to sort on, , , , ,
# 6.1, 2.9, 4.7, 1.4, Iris-versicolor, 0.880081854, , , , ,
# 5, 3.5, 1.6, 0.6, Iris-setosa, 0.960217308, , , , ,
# 5.4, 3, 4.5, 1.5, Iris-versicolor, 0.467236101, , , , ,
# 5.6, 2.9, 3.6, 1.3, Iris-versicolor, 0.54526295, , , , ,
# 6.9, 3.1, 5.1, 2.3, Iris-virginica, 0.08909534, , , , ,
# 5.8, 2.7, 5.1, 1.9, Iris-virginica, 0.514275209, , , , ,
# 5.6, 2.5, 3.9, 1.1, Iris-versicolor, 0.000827239, , , , ,
# 5.6, 3, 4.1, 1.3, Iris-versicolor, 0.234331292, , , , ,
# 6.1, 2.8, 4, 1.3, Iris-versicolor, 0.144621822, , , , ,
# 7.7, 3, 6.1, 2.3, Iris-virginica, 0.120632235, , , , ,
# 5.5, 2.4, 3.7, 1, Iris-versicolor, 0.114143517, , , , ,
# ...

# %%
import pandas as pd
iris=pd.read_csv("iris-data.csv")

# %%
iris.head()
# Oh I love pandas dataframes!
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth             Name  \
# 0          6.1         2.9          4.7         1.4  Iris-versicolor
# 1          5.0         3.5          1.6         0.6      Iris-setosa
# 2          5.4         3.0          4.5         1.5  Iris-versicolor
# 3          5.6         2.9          3.6         1.3  Iris-versicolor
# 4          6.9         3.1          5.1         2.3   Iris-virginica
#
#    random number to sort on Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                  0.880082        NaN         NaN         NaN         NaN
# 1                  0.960217        NaN         NaN         NaN         NaN
# 2                  0.467236        NaN         NaN         NaN         NaN
# 3                  0.545263        NaN         NaN         NaN         NaN
# 4                  0.089095        NaN         NaN         NaN         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
import pandas as pd
iris=pd.read_csv("iris-data.csv",header=9)

# %%
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth             Name  \
# 0          6.1         2.9          4.7         1.4  Iris-versicolor
# 1          5.0         3.5          1.6         0.6      Iris-setosa
# 2          5.4         3.0          4.5         1.5  Iris-versicolor
# 3          5.6         2.9          3.6         1.3  Iris-versicolor
# 4          6.9         3.1          5.1         2.3   Iris-virginica
#
#    random number to sort on Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0                  0.880082        NaN         NaN         NaN         NaN
# 1                  0.960217        NaN         NaN         NaN         NaN
# 2                  0.467236        NaN         NaN         NaN         NaN
# 3                  0.545263        NaN         NaN         NaN         NaN
# 4                  0.089095        NaN         NaN         NaN         NaN
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
outcomes = pd.read_csv("Austin_Animal_Center_Outcomes.csv")

# %%
print(outcomes[1:10])
# Out:
#   Animal ID          Name                DateTime               MonthYear  \
# 1   A658751         Benji  11/13/2016 01:38:00 PM  11/13/2016 01:38:00 PM
# 2   A721285           NaN  02/24/2016 02:42:00 PM  02/24/2016 02:42:00 PM
# 3   A746650          Rose  04/07/2017 11:58:00 AM  04/07/2017 11:58:00 AM
# 4   A750122  Happy Camper  05/24/2017 06:36:00 PM  05/24/2017 06:36:00 PM
# 5   A756696        Shakti  09/01/2017 11:23:00 AM  09/01/2017 11:23:00 AM
# 6   A707443           NaN  07/13/2015 01:50:00 PM  07/13/2015 01:50:00 PM
# 7   A684346           NaN  07/22/2014 04:04:00 PM  07/22/2014 04:04:00 PM
# 8   A754895          Miso  07/30/2017 12:03:00 PM  07/30/2017 12:03:00 PM
# 9   A666430          Lucy  11/07/2013 11:47:00 AM  11/07/2013 11:47:00 AM
#
#   Date of Birth     Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 1    07/14/2011  Return to Owner             NaN         Dog    Neutered Male
# ...

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()

# %%
# I need to change these to numbers
X = outcomes[["Animal Type","Color","Breed","Age upon Outcome"]]

# %%
# and these....
y = outcomes[["Outcome Type"]]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-d4a1ad427098> in <module>()
# ----> 1 clf = clf.fit(X,y)
#
# /Users/kaisa/anaconda/envs/py34/lib/python3.4/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     737             sample_weight=sample_weight,
#     738             check_input=check_input,
# --> 739             X_idx_sorted=X_idx_sorted)
#     740         return self
#     741
#
# /Users/kaisa/anaconda/envs/py34/lib/python3.4/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     120         random_state = check_random_state(self.random_state)
#     121         if check_input:
# --> 122             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     123             y = check_array(y, ensure_2d=False, dtype=None)
#     124             if issparse(X):
# ...

# %% [markdown]
# We have categorical data here -- need to use binary or one-hot encoding to switch it to numeric if we want to use SKLearn. In R, can deal with categorical as such!
